# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
data = pd.read_csv('box_office_predictions.csv')

# %%
data.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    7.8    Sam Worthington
# 1          Titanic (1997)  PG-13      194    7.8  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    7.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    8.1  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    9.0     Christian Bale
#
#                                    studio    votes       profit  year
# 0  Twentieth Century Fox Film Corporation   958400  523507625.0  2009
# ...

# %%
print("Columns with missing values", data.isna().sum())
# Out:
# Columns with missing values budget      0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# runtime     0
# score       0
# star        0
# studio      0
# votes       0
# profit      0
# year        0
# dtype: int64

# %%
data['profit'] = data['gross'] - data['budget']

# %%
np.corrcoef(data['profit'], data['score'])
# Out:
# array([[1.        , 0.19406541],
#        [0.19406541, 1.        ]])

# %%
np.corrcoef(data['profit'], data['votes'])
# Out:
# array([[1.       , 0.4802336],
#        [0.4802336, 1.       ]])

# %%
for i in range(0,len(data.index)):
  data.loc[i,'year'] = data.loc[i,'name'].split(" ",)[-1].strip('()')

# %%
data.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    7.8    Sam Worthington
# 1          Titanic (1997)  PG-13      194    7.8  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    7.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    8.1  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    9.0     Christian Bale
#
#                                    studio    votes       profit  year
# 0  Twentieth Century Fox Film Corporation   958400  523507625.0  2009
# ...

# %%
categorical = ['country','director','genre','rating','star','studio']

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# budget       338
# country       52
# director    2549
# genre         17
# gross       5987
# name        6000
# rating        13
# runtime      131
# score         74
# star        2317
# studio      1996
# votes       5775
# profit      5991
# year          31
# dtype: int64

# %%
yearvalues = data['year'].unique()
print(yearvalues)
# Out:
# ['2009' '1997' '2015' '2012' '2008' '2016' '1999' '2004' '2013' '2006'
#  '2010' '2002' '1993' '2011' '2003' '2005' '2014' '2007' '1994' '2001'
#  '1996' '2000' '1989' '1991' '1990' '1992' '1998' '1995' '1986' '1988'
#  '1987']

# %%
data.drop(columns=['name','gross','votes'],inplace=True)

# %%
data.head()
# Out:
#         budget country           director   genre rating  runtime  score  \
# 0  237000000.0      UK      James Cameron  Action  PG-13      162    7.8
# 1  200000000.0     USA      James Cameron   Drama  PG-13      194    7.8
# 2  150000000.0     USA    Colin Trevorrow  Action  PG-13      124    7.0
# 3  220000000.0     USA        Joss Whedon  Action  PG-13      143    8.1
# 4  185000000.0     USA  Christopher Nolan  Action  PG-13      152    9.0
#
#                 star                                  studio       profit  \
# 0    Sam Worthington  Twentieth Century Fox Film Corporation  523507625.0
# 1  Leonardo DiCaprio  Twentieth Century Fox Film Corporation  458672302.0
# 2        Chris Pratt                      Universal Pictures  502270625.0
# 3  Robert Downey Jr.                          Marvel Studios  403357910.0
# 4     Christian Bale                            Warner Bros.  349858444.0
#
#    year
# 0  2009
# 1  1997
# 2  2015
# 3  2012
# 4  2008

# %%
train = data.loc[~data['year'].isin(['2015','2016'])]
test = data.loc[data['year'].isin(['2015','2016'])]

# %%
test.head()
# Out:
#          budget country         director      genre rating  runtime  score  \
# 2   150000000.0     USA  Colin Trevorrow     Action  PG-13      124    7.0
# 5   200000000.0     USA   Gareth Edwards     Action  PG-13      133    7.9
# 7   250000000.0     USA      Joss Whedon     Action  PG-13      141    7.4
# 14  250000000.0     USA    Anthony Russo     Action  PG-13      147    7.9
# 26  175000000.0      UK      Jon Favreau  Adventure     PG      106    7.5
#
#                  star                  studio       profit  year
# 2         Chris Pratt      Universal Pictures  502270625.0  2015
# 5      Felicity Jones               Lucasfilm  332177324.0  2016
# 7   Robert Downey Jr.          Marvel Studios  209005868.0  2015
# 14        Chris Evans          Marvel Studios  158084349.0  2016
# 26         Neel Sethi  Fairview Entertainment  189001123.0  2016

# %%
train.head()
# Out:
#         budget country           director   genre rating  runtime  score  \
# 0  237000000.0      UK      James Cameron  Action  PG-13      162    7.8
# 1  200000000.0     USA      James Cameron   Drama  PG-13      194    7.8
# 3  220000000.0     USA        Joss Whedon  Action  PG-13      143    8.1
# 4  185000000.0     USA  Christopher Nolan  Action  PG-13      152    9.0
# 6  115000000.0     USA       George Lucas  Action     PG      136    6.5
#
#                 star                                  studio       profit  \
# 0    Sam Worthington  Twentieth Century Fox Film Corporation  523507625.0
# 1  Leonardo DiCaprio  Twentieth Century Fox Film Corporation  458672302.0
# 3  Robert Downey Jr.                          Marvel Studios  403357910.0
# 4     Christian Bale                            Warner Bros.  349858444.0
# 6      Ewan McGregor                               Lucasfilm  359544677.0
#
#    year
# 0  2009
# 1  1997
# 3  2012
# 4  2008
# 6  1999
